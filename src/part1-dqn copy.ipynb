# %%
# imports:
# !pip install gymnasium==1.0.0
# !pip install ale-py
# !pip install wandb
# !pip install torchsummary
import gymnasium as gym
import ale_py
from gymnasium.wrappers import MaxAndSkipObservation, ResizeObservation, GrayscaleObservation, FrameStackObservation, ReshapeObservation

import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
from torchsummary import summary

import collections

import wandb
import datetime
# Out:
# Requirement already satisfied: gymnasium==1.0.0 in c:\users\arroc\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\arroc\anaconda3\lib\site-packages (from gymnasium==1.0.0) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\arroc\anaconda3\lib\site-packages (from gymnasium==1.0.0) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\arroc\anaconda3\lib\site-packages (from gymnasium==1.0.0) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\arroc\anaconda3\lib\site-packages (from gymnasium==1.0.0) (0.0.4)
# Requirement already satisfied: ale-py in c:\users\arroc\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy>1.20 in c:\users\arroc\anaconda3\lib\site-packages (from ale-py) (1.24.3)
# Requirement already satisfied: wandb in c:\users\arroc\anaconda3\lib\site-packages (0.18.5)
# Requirement already satisfied: click!=8.0.0,>=7.1 in c:\users\arroc\anaconda3\lib\site-packages (from wandb) (8.0.4)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\arroc\anaconda3\lib\site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in c:\users\arroc\anaconda3\lib\site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in c:\users\arroc\anaconda3\lib\site-packages (from wandb) (2.5.2)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in c:\users\arroc\anaconda3\lib\site-packages (from wandb) (4.25.3)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\arroc\anaconda3\lib\site-packages (from wandb) (5.9.0)
# Requirement already satisfied: pyyaml in c:\users\arroc\anaconda3\lib\site-packages (from wandb) (6.0)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\arroc\anaconda3\lib\site-packages (from wandb) (2.31.0)
# Requirement already satisfied: sentry-sdk>=2.0.0 in c:\users\arroc\anaconda3\lib\site-packages (from wandb) (2.17.0)
# Requirement already satisfied: setproctitle in c:\users\arroc\anaconda3\lib\site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in c:\users\arroc\anaconda3\lib\site-packages (from wandb) (68.0.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in c:\users\arroc\anaconda3\lib\site-packages (from wandb) (4.11.0)
# Requirement already satisfied: colorama in c:\users\arroc\anaconda3\lib\site-packages (from click!=8.0.0,>=7.1->wandb) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in c:\users\arroc\anaconda3\lib\site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\arroc\anaconda3\lib\site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arroc\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arroc\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arroc\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arroc\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\arroc\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: torchsummary in c:\users\arroc\anaconda3\lib\site-packages (1.5.1)

# %%
# version
print("Using Gymnasium version {}".format(gym.__version__))

ENV_NAME = "ALE/Breakout-v5"
test_env = gym.make(ENV_NAME, render_mode='rgb_array')

print(test_env.unwrapped.get_action_meanings())
print(test_env.observation_space.shape)
# Out:
# Using Gymnasium version 1.0.0
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT']
# (210, 160, 3)

# %%
# Source: M3-2_Example_1a (DQN on Pong, train)
class ImageToPyTorch(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        old_shape = self.observation_space.shape
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0, shape=(old_shape[-1], old_shape[0], old_shape[1]), dtype=np.float32)

    def observation(self, observation):
        return np.moveaxis(observation, 2, 0)


class ScaledFloatFrame(gym.ObservationWrapper):
    def observation(self, obs):
        return np.array(obs).astype(np.float32) / 255.0


def make_env(env_name):
    env = gym.make(env_name, render_mode='rgb_array')
    print("Standard Env.        : {}".format(env.observation_space.shape))
    env = MaxAndSkipObservation(env, skip=4)
    print("MaxAndSkipObservation: {}".format(env.observation_space.shape))
    #env = FireResetEnv(env)
    env = ResizeObservation(env, (84, 84))
    print("ResizeObservation    : {}".format(env.observation_space.shape))
    env = GrayscaleObservation(env, keep_dim=True)
    print("GrayscaleObservation : {}".format(env.observation_space.shape))
    env = ImageToPyTorch(env)
    print("ImageToPyTorch       : {}".format(env.observation_space.shape))
    env = ReshapeObservation(env, (84, 84))
    print("ReshapeObservation   : {}".format(env.observation_space.shape))
    env = FrameStackObservation(env, stack_size=4)
    print("FrameStackObservation: {}".format(env.observation_space.shape))
    env = ScaledFloatFrame(env)
    print("ScaledFloatFrame     : {}".format(env.observation_space.shape))

    return env

env=make_env(ENV_NAME)
# Out:
# Standard Env.        : (210, 160, 3)
# MaxAndSkipObservation: (210, 160, 3)
# ResizeObservation    : (84, 84, 3)
# GrayscaleObservation : (84, 84, 1)
# ImageToPyTorch       : (1, 84, 84)
# ReshapeObservation   : (84, 84)
# FrameStackObservation: (4, 84, 84)
# ScaledFloatFrame     : (4, 84, 84)

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %%
# Source: This code is adapted form the following github repository: https://github.com/dxyang/DQN_pytorch/blob/master/model.py
class DuelingDQN(nn.Module):
    def __init__(self, input_shape, num_actions):
        super(DuelingDQN, self).__init__()
        self.num_actions = num_actions

        # Common feature extraction
        self.feature_extractor = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten()
        )

        # Advantage stream
        self.advantage = nn.Sequential(
            nn.Linear(64 * 7 * 7, 512),
            nn.ReLU(),
            nn.Linear(512, num_actions)
        )

        # Value stream
        self.value = nn.Sequential(
            nn.Linear(64 * 7 * 7, 512),
            nn.ReLU(),
            nn.Linear(512, 1)
        )

    def forward(self, x):
        # Extract features
        features = self.feature_extractor(x)

        # Compute advantage and value streams
        adv = self.advantage(features)
        val = self.value(features).expand(x.size(0), self.num_actions)

        # Combine streams into Q-values
        q_values = val + adv - adv.mean(dim=1, keepdim=True)
        return q_values

# %%
MEAN_REWARD_BOUND = 100         # Max is 864
NUMBER_OF_REWARDS_TO_AVERAGE = 10

GAMMA = 0.99

BATCH_SIZE = 32
LEARNING_RATE = 0.0001

EXPERIENCE_REPLAY_SIZE = 50000 
SYNC_TARGET_NETWORK = 1000 

EPS_START = 1.0
EPS_DECAY = 0.999985 
EPS_MIN = 0.05

INITIAL_BETA=0.4

# %%
Experience = collections.namedtuple('Experience', field_names=['state', 'action', 'reward', 'done', 'new_state'])

class ExperienceReplay:
    def __init__(self, capacity):
        self.buffer = collections.deque(maxlen=capacity)

    def __len__(self):
        return len(self.buffer)

    def append(self, experience):
        self.buffer.append(experience)

    def sample(self, BATCH_SIZE):
        indices = np.random.choice(len(self.buffer), BATCH_SIZE, replace=False)
        states, actions, rewards, dones, next_states = zip(*[self.buffer[idx] for idx in indices])
        
        return np.array(states), np.array(actions), np.array(rewards, dtype=np.float32), \
               np.array(dones, dtype=np.uint8), np.array(next_states)

# %%
class DQNAgent:
    def __init__(self, env, exp_replay_buffer):
        self.env = env
        self.exp_replay_buffer = exp_replay_buffer
        self._reset()

    def _reset(self):
        self.current_state = self.env.reset()[0]
        self.total_reward = 0.0

    def step(self, net, epsilon=0.0, device="cpu"):
        done_reward = None
        if np.random.random() < epsilon:
            action = env.action_space.sample()
        else:
            state_ = np.array([self.current_state])
            state = torch.tensor(state_).to(device)
            q_vals = net(state)
            _, act_ = torch.max(q_vals, dim=1)
            action = int(act_.item())

        new_state, reward, terminated, truncated, _ = self.env.step(action)
        is_done = terminated or truncated
        self.total_reward += reward

        clipped_reward=np.sing(reward) #Here we clip the reward for training stability, as shown in the deepmind's paper: 

        exp = Experience(self.current_state, action, clipped_reward, is_done, new_state)
        self.exp_replay_buffer.append(exp)
        self.current_state = new_state

        if is_done:
            done_reward = self.total_reward
            self._reset()

        return done_reward

# %%
# login
wandb.login()

# start a new wandb run to track this script
wandb.init(
    project="Part1_DQN",
    config={
        "gamma": GAMMA,
        "learning_rate": LEARNING_RATE,
        "eps_start": EPS_START,
        "eps_decay": EPS_DECAY,
        "expereince_replay_size": EXPERIENCE_REPLAY_SIZE,
        "sync_target_network": SYNC_TARGET_NETWORK
    }
)
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: arroch35 (arroch35-organitzation). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>c:\Users\arroc\OneDrive\Escritorio\Apuntes\UAB\3rd year\P_of_ML\Project\Reinfrocement-Learning-Project\src\wandb\run-20241201_230835-24cl6npg</code>
# Syncing run <strong><a href='https://wandb.ai/arroch35-organitzation/Part1_DQN/runs/24cl6npg' target="_blank">fragrant-energy-18</a></strong> to <a href='https://wandb.ai/arroch35-organitzation/Part1_DQN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/arroch35-organitzation/Part1_DQN' target="_blank">https://wandb.ai/arroch35-organitzation/Part1_DQN</a>
#  View run at <a href='https://wandb.ai/arroch35-organitzation/Part1_DQN/runs/24cl6npg' target="_blank">https://wandb.ai/arroch35-organitzation/Part1_DQN/runs/24cl6npg</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/arroch35-organitzation/Part1_DQN/runs/24cl6npg?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
print(">>> Training starts at ",datetime.datetime.now())
# Out:
# >>> Training starts at  2024-12-01 23:08:38.294099

# %%
net = DuelingDQN(env.observation_space.shape, env.action_space.n).to(device)
target_net = DuelingDQN(env.observation_space.shape, env.action_space.n).to(device)

# Here we replace standard buffer with the PER buffer
buffer = ExperienceReplay(EXPERIENCE_REPLAY_SIZE)
agent = DQNAgent(env, buffer)

epsilon = EPS_START
optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)
total_rewards = []
losses = []
step_number = 0
spected_min_reward=20
steps_best_model_obtained=None
spected_min_reward_achieved=False


while True:
    step_number += 1
    if(step_number % 2 == 0): epsilon = max(epsilon * EPS_DECAY, EPS_MIN)

    # Here we update beta from INITIAL_BETA to 1.0
    buffer.beta = min(1.0, buffer.beta + (1.0 - INITIAL_BETA) / 500000) # This is divided by 500000 because this is the expected number of steps for the algorithm to run. In this way, beta will be 1.0 when the algorithm reach the 500000 steps

        
    reward = agent.step(net, epsilon, device=device)
    if reward is not None:
        total_rewards.append(reward)

        mean_reward = np.mean(total_rewards[-NUMBER_OF_REWARDS_TO_AVERAGE:])

        print(f"Step:{step_number} | Total games:{len(total_rewards)} | Mean reward: {mean_reward:.3f}  (epsilon used: {epsilon:.2f})")
        wandb.log({"epsilon": epsilon, "reward_mean": mean_reward, "reward": reward}, step=step_number)

        if mean_reward > spected_min_reward:
            name="Part1_DQN_"+str(int(mean_reward))
            torch.save(net.state_dict(), f"../models/{name}.dat")
            print("New best model saved.")
            spected_min_reward_achieved=True
            spected_min_reward +=5
            steps_best_model_obtained=step_number

        if spected_min_reward_achieved and (step_number > steps_best_model_obtained + 100000):
            print("Model stacked, not learning.")
            print("Stopping the execution.")
            break
        
        if mean_reward > MEAN_REWARD_BOUND:
            print(f"SOLVED in {step_number} steps and {len(total_rewards)} games")
            break

    if len(buffer) < EXPERIENCE_REPLAY_SIZE:
        continue

    states_, actions_, rewards_, dones_, next_states_ = buffer.sample(BATCH_SIZE)
    #importance = torch.tensor(importance, dtype=torch.float32).to(device)

    states = torch.tensor(states_).to(device)
    next_states = torch.tensor(next_states_).to(device)
    actions = torch.tensor(actions_).to(device)
    rewards = torch.tensor(rewards_).to(device)
    dones = torch.BoolTensor(dones_).to(device)

    Q_values = net(states).gather(1, actions.unsqueeze(-1)).squeeze(-1)

    # Get the actions selected by the policy network
    policy_actions = net(next_states).argmax(1).unsqueeze(1)  # Shape: [batch_size, 1]

    # Use the target network to compute the value of those actions
    next_state_values = target_net(next_states).gather(1, policy_actions).squeeze(1) # Doble DQN
    next_state_values[dones] = 0.0
    next_state_values = next_state_values.detach()

    expected_Q_values = next_state_values * GAMMA + rewards


    #errors = torch.abs(Q_values - expected_Q_values).detach().cpu().numpy()  # Here we calculate the TD errors
    #loss = (importance * nn.MSELoss(reduction='none')(Q_values, expected_Q_values)).mean() # Here we use reduction='none' because we want to calculate the MSE element by element first, multiply it by the importance weights, and then take the mean
    loss = nn.MSELoss()(Q_values, expected_Q_values)

    # We update the buffer priorities based on the TD errors
    #buffer.update_priorities(indices, errors)

    losses.append(loss.item())
    mean_losses = np.mean(losses[-NUMBER_OF_REWARDS_TO_AVERAGE:])
    wandb.log({"loss_mean": mean_losses, "loss": loss.item()}, step=step_number)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if step_number % SYNC_TARGET_NETWORK == 0:
        target_net.load_state_dict(net.state_dict())
# Out:
# Step:58 | Total games:1 | Mean reward: 1.000  (epsilon used: 1.00)
# Step:108 | Total games:2 | Mean reward: 1.000  (epsilon used: 1.00)
# Step:178 | Total games:3 | Mean reward: 1.667  (epsilon used: 1.00)
# Step:229 | Total games:4 | Mean reward: 1.750  (epsilon used: 1.00)
# Step:283 | Total games:5 | Mean reward: 1.800  (epsilon used: 1.00)
# Step:326 | Total games:6 | Mean reward: 1.667  (epsilon used: 1.00)
# Step:387 | Total games:7 | Mean reward: 1.571  (epsilon used: 1.00)
# Step:442 | Total games:8 | Mean reward: 1.625  (epsilon used: 1.00)
# Step:510 | Total games:9 | Mean reward: 1.444  (epsilon used: 1.00)
# Step:578 | Total games:10 | Mean reward: 1.600  (epsilon used: 1.00)
# Step:652 | Total games:11 | Mean reward: 1.700  (epsilon used: 1.00)
# Step:696 | Total games:12 | Mean reward: 1.600  (epsilon used: 0.99)
# Step:770 | Total games:13 | Mean reward: 1.600  (epsilon used: 0.99)
# Step:838 | Total games:14 | Mean reward: 1.600  (epsilon used: 0.99)
# Step:923 | Total games:15 | Mean reward: 1.700  (epsilon used: 0.99)
# Step:981 | Total games:16 | Mean reward: 1.600  (epsilon used: 0.99)
# Step:1045 | Total games:17 | Mean reward: 1.700  (epsilon used: 0.99)
# Step:1104 | Total games:18 | Mean reward: 1.500  (epsilon used: 0.99)
# Step:1150 | Total games:19 | Mean reward: 1.600  (epsilon used: 0.99)
# Step:1188 | Total games:20 | Mean reward: 1.300  (epsilon used: 0.99)
# Step:1280 | Total games:21 | Mean reward: 1.600  (epsilon used: 0.99)
# Step:1338 | Total games:22 | Mean reward: 1.800  (epsilon used: 0.99)
# Step:1389 | Total games:23 | Mean reward: 1.600  (epsilon used: 0.99)
# Step:1426 | Total games:24 | Mean reward: 1.400  (epsilon used: 0.99)
# Step:1477 | Total games:25 | Mean reward: 1.200  (epsilon used: 0.99)
# Step:1537 | Total games:26 | Mean reward: 1.500  (epsilon used: 0.99)
# Step:1602 | Total games:27 | Mean reward: 1.500  (epsilon used: 0.99)
# Step:1666 | Total games:28 | Mean reward: 1.700  (epsilon used: 0.99)
# Step:1716 | Total games:29 | Mean reward: 1.700  (epsilon used: 0.99)
# Step:1802 | Total games:30 | Mean reward: 2.100  (epsilon used: 0.99)
# Step:1874 | Total games:31 | Mean reward: 1.800  (epsilon used: 0.99)
# Step:1925 | Total games:32 | Mean reward: 1.800  (epsilon used: 0.99)
# Step:1985 | Total games:33 | Mean reward: 1.900  (epsilon used: 0.99)
# Step:2020 | Total games:34 | Mean reward: 1.900  (epsilon used: 0.98)
# Step:2080 | Total games:35 | Mean reward: 1.900  (epsilon used: 0.98)
# Step:2133 | Total games:36 | Mean reward: 1.800  (epsilon used: 0.98)
# Step:2193 | Total games:37 | Mean reward: 1.800  (epsilon used: 0.98)
# Step:2239 | Total games:38 | Mean reward: 1.700  (epsilon used: 0.98)
# Step:2303 | Total games:39 | Mean reward: 1.800  (epsilon used: 0.98)
# Step:2357 | Total games:40 | Mean reward: 1.500  (epsilon used: 0.98)
# Step:2403 | Total games:41 | Mean reward: 1.300  (epsilon used: 0.98)
# Step:2477 | Total games:42 | Mean reward: 1.400  (epsilon used: 0.98)
# Step:2531 | Total games:43 | Mean reward: 1.400  (epsilon used: 0.98)
# Step:2576 | Total games:44 | Mean reward: 1.400  (epsilon used: 0.98)
# Step:2631 | Total games:45 | Mean reward: 1.500  (epsilon used: 0.98)
# Step:2693 | Total games:46 | Mean reward: 1.500  (epsilon used: 0.98)
# Step:2741 | Total games:47 | Mean reward: 1.400  (epsilon used: 0.98)
# Step:2800 | Total games:48 | Mean reward: 1.500  (epsilon used: 0.98)
# Step:2874 | Total games:49 | Mean reward: 1.700  (epsilon used: 0.98)
# Step:2922 | Total games:50 | Mean reward: 1.700  (epsilon used: 0.98)
# Step:2988 | Total games:51 | Mean reward: 2.000  (epsilon used: 0.98)
# Step:3040 | Total games:52 | Mean reward: 1.800  (epsilon used: 0.98)
# Step:3119 | Total games:53 | Mean reward: 2.100  (epsilon used: 0.98)
# Step:3174 | Total games:54 | Mean reward: 2.200  (epsilon used: 0.98)
# Step:3299 | Total games:55 | Mean reward: 2.600  (epsilon used: 0.98)
# Step:3357 | Total games:56 | Mean reward: 2.500  (epsilon used: 0.98)
# Step:3417 | Total games:57 | Mean reward: 2.500  (epsilon used: 0.97)
# Step:3474 | Total games:58 | Mean reward: 2.400  (epsilon used: 0.97)
# Step:3538 | Total games:59 | Mean reward: 2.300  (epsilon used: 0.97)
# Step:3619 | Total games:60 | Mean reward: 2.500  (epsilon used: 0.97)
# Step:3670 | Total games:61 | Mean reward: 2.200  (epsilon used: 0.97)
# Step:3725 | Total games:62 | Mean reward: 2.300  (epsilon used: 0.97)
# Step:3785 | Total games:63 | Mean reward: 2.000  (epsilon used: 0.97)
# Step:3846 | Total games:64 | Mean reward: 2.000  (epsilon used: 0.97)
# Step:3910 | Total games:65 | Mean reward: 1.600  (epsilon used: 0.97)
# Step:3962 | Total games:66 | Mean reward: 1.600  (epsilon used: 0.97)
# Step:4029 | Total games:67 | Mean reward: 1.700  (epsilon used: 0.97)
# Step:4084 | Total games:68 | Mean reward: 1.700  (epsilon used: 0.97)
# Step:4156 | Total games:69 | Mean reward: 1.700  (epsilon used: 0.97)
# Step:4200 | Total games:70 | Mean reward: 1.500  (epsilon used: 0.97)
# Step:4268 | Total games:71 | Mean reward: 1.800  (epsilon used: 0.97)
# Step:4342 | Total games:72 | Mean reward: 1.800  (epsilon used: 0.97)
# Step:4423 | Total games:73 | Mean reward: 2.000  (epsilon used: 0.97)
# Step:4472 | Total games:74 | Mean reward: 1.900  (epsilon used: 0.97)
# Step:4548 | Total games:75 | Mean reward: 2.000  (epsilon used: 0.97)
# Step:4595 | Total games:76 | Mean reward: 2.000  (epsilon used: 0.97)
# Step:4696 | Total games:77 | Mean reward: 2.400  (epsilon used: 0.97)
# Step:4753 | Total games:78 | Mean reward: 2.400  (epsilon used: 0.96)
# Step:4796 | Total games:79 | Mean reward: 2.200  (epsilon used: 0.96)
# Step:4861 | Total games:80 | Mean reward: 2.300  (epsilon used: 0.96)
# Step:4907 | Total games:81 | Mean reward: 2.000  (epsilon used: 0.96)
# Step:4959 | Total games:82 | Mean reward: 1.900  (epsilon used: 0.96)
# Step:5020 | Total games:83 | Mean reward: 1.700  (epsilon used: 0.96)
# Step:5086 | Total games:84 | Mean reward: 2.000  (epsilon used: 0.96)
# Step:5168 | Total games:85 | Mean reward: 2.000  (epsilon used: 0.96)
# Step:5231 | Total games:86 | Mean reward: 2.100  (epsilon used: 0.96)
# Step:5290 | Total games:87 | Mean reward: 1.600  (epsilon used: 0.96)
# Step:5349 | Total games:88 | Mean reward: 1.600  (epsilon used: 0.96)
# Step:5387 | Total games:89 | Mean reward: 1.500  (epsilon used: 0.96)
# Step:5442 | Total games:90 | Mean reward: 1.500  (epsilon used: 0.96)
# Step:5513 | Total games:91 | Mean reward: 1.800  (epsilon used: 0.96)
# Step:5574 | Total games:92 | Mean reward: 2.000  (epsilon used: 0.96)
# Step:5639 | Total games:93 | Mean reward: 2.000  (epsilon used: 0.96)
# Step:5688 | Total games:94 | Mean reward: 1.800  (epsilon used: 0.96)
# Step:5743 | Total games:95 | Mean reward: 1.600  (epsilon used: 0.96)
# Step:5790 | Total games:96 | Mean reward: 1.400  (epsilon used: 0.96)
# Step:5850 | Total games:97 | Mean reward: 1.400  (epsilon used: 0.96)
# Step:5913 | Total games:98 | Mean reward: 1.600  (epsilon used: 0.96)
# Step:5997 | Total games:99 | Mean reward: 1.800  (epsilon used: 0.96)
# Step:6036 | Total games:100 | Mean reward: 1.600  (epsilon used: 0.96)
# Step:6110 | Total games:101 | Mean reward: 1.500  (epsilon used: 0.96)
# Step:6169 | Total games:102 | Mean reward: 1.500  (epsilon used: 0.95)
# Step:6243 | Total games:103 | Mean reward: 1.500  (epsilon used: 0.95)
# Step:6297 | Total games:104 | Mean reward: 1.500  (epsilon used: 0.95)
# Step:6365 | Total games:105 | Mean reward: 1.600  (epsilon used: 0.95)
# Step:6423 | Total games:106 | Mean reward: 1.800  (epsilon used: 0.95)
# Step:6507 | Total games:107 | Mean reward: 2.100  (epsilon used: 0.95)
# Step:6565 | Total games:108 | Mean reward: 2.000  (epsilon used: 0.95)
# Step:6619 | Total games:109 | Mean reward: 1.900  (epsilon used: 0.95)
# Step:6695 | Total games:110 | Mean reward: 2.200  (epsilon used: 0.95)
# Step:6746 | Total games:111 | Mean reward: 2.000  (epsilon used: 0.95)
# Step:6801 | Total games:112 | Mean reward: 1.900  (epsilon used: 0.95)
# Step:6870 | Total games:113 | Mean reward: 1.800  (epsilon used: 0.95)
# Step:6929 | Total games:114 | Mean reward: 1.900  (epsilon used: 0.95)
# Step:6978 | Total games:115 | Mean reward: 1.700  (epsilon used: 0.95)
# Step:7043 | Total games:116 | Mean reward: 1.700  (epsilon used: 0.95)
# Step:7100 | Total games:117 | Mean reward: 1.400  (epsilon used: 0.95)
# Step:7152 | Total games:118 | Mean reward: 1.300  (epsilon used: 0.95)
# Step:7231 | Total games:119 | Mean reward: 1.400  (epsilon used: 0.95)
# Step:7307 | Total games:120 | Mean reward: 1.300  (epsilon used: 0.95)
# Step:7377 | Total games:121 | Mean reward: 1.500  (epsilon used: 0.95)
# Step:7425 | Total games:122 | Mean reward: 1.400  (epsilon used: 0.95)
# Step:7489 | Total games:123 | Mean reward: 1.600  (epsilon used: 0.95)
# Step:7543 | Total games:124 | Mean reward: 1.400  (epsilon used: 0.95)
# Step:7597 | Total games:125 | Mean reward: 1.500  (epsilon used: 0.94)
# Step:7680 | Total games:126 | Mean reward: 1.500  (epsilon used: 0.94)
# Step:7722 | Total games:127 | Mean reward: 1.400  (epsilon used: 0.94)
# Step:7806 | Total games:128 | Mean reward: 1.600  (epsilon used: 0.94)
# Step:7878 | Total games:129 | Mean reward: 1.600  (epsilon used: 0.94)
# Step:7946 | Total games:130 | Mean reward: 1.500  (epsilon used: 0.94)
# Step:7998 | Total games:131 | Mean reward: 1.400  (epsilon used: 0.94)
# Step:8031 | Total games:132 | Mean reward: 1.300  (epsilon used: 0.94)
# Step:8090 | Total games:133 | Mean reward: 1.100  (epsilon used: 0.94)
# Step:8156 | Total games:134 | Mean reward: 1.200  (epsilon used: 0.94)
# Step:8238 | Total games:135 | Mean reward: 1.400  (epsilon used: 0.94)
# Step:8301 | Total games:136 | Mean reward: 1.400  (epsilon used: 0.94)
# Step:8364 | Total games:137 | Mean reward: 1.700  (epsilon used: 0.94)
# Step:8435 | Total games:138 | Mean reward: 1.700  (epsilon used: 0.94)
# Step:8489 | Total games:139 | Mean reward: 1.600  (epsilon used: 0.94)
# Step:8545 | Total games:140 | Mean reward: 1.600  (epsilon used: 0.94)
# Step:8602 | Total games:141 | Mean reward: 1.700  (epsilon used: 0.94)
# Step:8655 | Total games:142 | Mean reward: 1.900  (epsilon used: 0.94)
# Step:8723 | Total games:143 | Mean reward: 2.100  (epsilon used: 0.94)
# Step:8791 | Total games:144 | Mean reward: 2.400  (epsilon used: 0.94)
# Step:8856 | Total games:145 | Mean reward: 2.100  (epsilon used: 0.94)
# Step:8920 | Total games:146 | Mean reward: 2.100  (epsilon used: 0.94)
# Step:8972 | Total games:147 | Mean reward: 1.800  (epsilon used: 0.93)
# Step:9034 | Total games:148 | Mean reward: 1.700  (epsilon used: 0.93)
# Step:9103 | Total games:149 | Mean reward: 1.900  (epsilon used: 0.93)
# Step:9193 | Total games:150 | Mean reward: 2.300  (epsilon used: 0.93)
# Step:9253 | Total games:151 | Mean reward: 2.200  (epsilon used: 0.93)
# Step:9331 | Total games:152 | Mean reward: 2.400  (epsilon used: 0.93)
# Step:9387 | Total games:153 | Mean reward: 2.300  (epsilon used: 0.93)
# Step:9442 | Total games:154 | Mean reward: 2.000  (epsilon used: 0.93)
# Step:9528 | Total games:155 | Mean reward: 2.300  (epsilon used: 0.93)
# Step:9593 | Total games:156 | Mean reward: 2.400  (epsilon used: 0.93)
# Step:9661 | Total games:157 | Mean reward: 2.700  (epsilon used: 0.93)
# Step:9730 | Total games:158 | Mean reward: 2.700  (epsilon used: 0.93)
# Step:9789 | Total games:159 | Mean reward: 2.400  (epsilon used: 0.93)
# Step:9837 | Total games:160 | Mean reward: 1.900  (epsilon used: 0.93)
# Step:9896 | Total games:161 | Mean reward: 2.000  (epsilon used: 0.93)
# Step:9953 | Total games:162 | Mean reward: 1.800  (epsilon used: 0.93)
# Step:10015 | Total games:163 | Mean reward: 1.900  (epsilon used: 0.93)
# Step:10071 | Total games:164 | Mean reward: 2.000  (epsilon used: 0.93)
# Step:10117 | Total games:165 | Mean reward: 1.800  (epsilon used: 0.93)
# Step:10163 | Total games:166 | Mean reward: 1.500  (epsilon used: 0.93)
# Step:10216 | Total games:167 | Mean reward: 1.200  (epsilon used: 0.93)
# Step:10297 | Total games:168 | Mean reward: 1.400  (epsilon used: 0.93)
# Step:10353 | Total games:169 | Mean reward: 1.600  (epsilon used: 0.93)
# Step:10406 | Total games:170 | Mean reward: 1.800  (epsilon used: 0.92)
# Step:10472 | Total games:171 | Mean reward: 1.800  (epsilon used: 0.92)
# Step:10526 | Total games:172 | Mean reward: 1.700  (epsilon used: 0.92)
# Step:10598 | Total games:173 | Mean reward: 1.600  (epsilon used: 0.92)
# Step:10652 | Total games:174 | Mean reward: 1.600  (epsilon used: 0.92)
# Step:10698 | Total games:175 | Mean reward: 1.600  (epsilon used: 0.92)
# Step:10764 | Total games:176 | Mean reward: 1.700  (epsilon used: 0.92)
# Step:10846 | Total games:177 | Mean reward: 2.200  (epsilon used: 0.92)
# Step:10905 | Total games:178 | Mean reward: 2.000  (epsilon used: 0.92)
# Step:10970 | Total games:179 | Mean reward: 2.000  (epsilon used: 0.92)
# Step:11038 | Total games:180 | Mean reward: 2.100  (epsilon used: 0.92)
# Step:11087 | Total games:181 | Mean reward: 2.000  (epsilon used: 0.92)
# Step:11176 | Total games:182 | Mean reward: 2.400  (epsilon used: 0.92)
# Step:11221 | Total games:183 | Mean reward: 2.300  (epsilon used: 0.92)
# Step:11290 | Total games:184 | Mean reward: 2.300  (epsilon used: 0.92)
# Step:11363 | Total games:185 | Mean reward: 2.500  (epsilon used: 0.92)
# Step:11413 | Total games:186 | Mean reward: 2.500  (epsilon used: 0.92)
# Step:11458 | Total games:187 | Mean reward: 2.000  (epsilon used: 0.92)
# Step:11513 | Total games:188 | Mean reward: 1.900  (epsilon used: 0.92)
# Step:11633 | Total games:189 | Mean reward: 2.200  (epsilon used: 0.92)
# Step:11696 | Total games:190 | Mean reward: 2.000  (epsilon used: 0.92)
# Step:11794 | Total games:191 | Mean reward: 2.400  (epsilon used: 0.92)
# Step:11839 | Total games:192 | Mean reward: 2.000  (epsilon used: 0.92)
# Step:11894 | Total games:193 | Mean reward: 2.000  (epsilon used: 0.91)
# Step:11964 | Total games:194 | Mean reward: 2.100  (epsilon used: 0.91)
# Step:12029 | Total games:195 | Mean reward: 1.900  (epsilon used: 0.91)
# Step:12089 | Total games:196 | Mean reward: 1.900  (epsilon used: 0.91)
# Step:12159 | Total games:197 | Mean reward: 2.100  (epsilon used: 0.91)
# Step:12256 | Total games:198 | Mean reward: 2.600  (epsilon used: 0.91)
# Step:12330 | Total games:199 | Mean reward: 2.500  (epsilon used: 0.91)
# Step:12380 | Total games:200 | Mean reward: 2.500  (epsilon used: 0.91)
# Step:12472 | Total games:201 | Mean reward: 2.500  (epsilon used: 0.91)
# Step:12542 | Total games:202 | Mean reward: 2.700  (epsilon used: 0.91)
# Step:12638 | Total games:203 | Mean reward: 2.900  (epsilon used: 0.91)
# Step:12689 | Total games:204 | Mean reward: 2.800  (epsilon used: 0.91)
# Step:12728 | Total games:205 | Mean reward: 2.700  (epsilon used: 0.91)
# Step:12783 | Total games:206 | Mean reward: 2.800  (epsilon used: 0.91)
# Step:12856 | Total games:207 | Mean reward: 2.900  (epsilon used: 0.91)
# Step:12922 | Total games:208 | Mean reward: 2.600  (epsilon used: 0.91)
# Step:13009 | Total games:209 | Mean reward: 2.600  (epsilon used: 0.91)
# Step:13080 | Total games:210 | Mean reward: 2.700  (epsilon used: 0.91)
# Step:13145 | Total games:211 | Mean reward: 2.500  (epsilon used: 0.91)
# Step:13199 | Total games:212 | Mean reward: 2.200  (epsilon used: 0.91)
# Step:13280 | Total games:213 | Mean reward: 2.300  (epsilon used: 0.91)
# Step:13321 | Total games:214 | Mean reward: 2.100  (epsilon used: 0.90)
# Step:13454 | Total games:215 | Mean reward: 2.900  (epsilon used: 0.90)
# Step:13512 | Total games:216 | Mean reward: 2.800  (epsilon used: 0.90)
# Step:13567 | Total games:217 | Mean reward: 2.700  (epsilon used: 0.90)
# Step:13642 | Total games:218 | Mean reward: 2.700  (epsilon used: 0.90)
# Step:13708 | Total games:219 | Mean reward: 2.400  (epsilon used: 0.90)
# Step:13774 | Total games:220 | Mean reward: 2.400  (epsilon used: 0.90)
# Step:13854 | Total games:221 | Mean reward: 2.500  (epsilon used: 0.90)
# Step:13913 | Total games:222 | Mean reward: 2.700  (epsilon used: 0.90)
# Step:13970 | Total games:223 | Mean reward: 2.400  (epsilon used: 0.90)
# Step:14036 | Total games:224 | Mean reward: 2.600  (epsilon used: 0.90)
# Step:14087 | Total games:225 | Mean reward: 1.900  (epsilon used: 0.90)
# Step:14162 | Total games:226 | Mean reward: 2.100  (epsilon used: 0.90)
# Step:14200 | Total games:227 | Mean reward: 1.900  (epsilon used: 0.90)
# Step:14281 | Total games:228 | Mean reward: 1.800  (epsilon used: 0.90)
# Step:14400 | Total games:229 | Mean reward: 2.300  (epsilon used: 0.90)
# Step:14481 | Total games:230 | Mean reward: 2.600  (epsilon used: 0.90)
# Step:14571 | Total games:231 | Mean reward: 2.600  (epsilon used: 0.90)
# Step:14633 | Total games:232 | Mean reward: 2.500  (epsilon used: 0.90)
# Step:14721 | Total games:233 | Mean reward: 2.900  (epsilon used: 0.90)
# Step:14810 | Total games:234 | Mean reward: 2.900  (epsilon used: 0.89)
# Step:14883 | Total games:235 | Mean reward: 3.100  (epsilon used: 0.89)
# Step:14966 | Total games:236 | Mean reward: 2.900  (epsilon used: 0.89)
# Step:15008 | Total games:237 | Mean reward: 2.900  (epsilon used: 0.89)
# Step:15082 | Total games:238 | Mean reward: 3.100  (epsilon used: 0.89)
# Step:15158 | Total games:239 | Mean reward: 2.800  (epsilon used: 0.89)
# Step:15234 | Total games:240 | Mean reward: 2.500  (epsilon used: 0.89)
# Step:15315 | Total games:241 | Mean reward: 2.400  (epsilon used: 0.89)
# Step:15386 | Total games:242 | Mean reward: 2.400  (epsilon used: 0.89)
# Step:15455 | Total games:243 | Mean reward: 2.100  (epsilon used: 0.89)
# Step:15529 | Total games:244 | Mean reward: 2.100  (epsilon used: 0.89)
# Step:15586 | Total games:245 | Mean reward: 2.000  (epsilon used: 0.89)
# Step:15648 | Total games:246 | Mean reward: 2.000  (epsilon used: 0.89)
# Step:15709 | Total games:247 | Mean reward: 2.100  (epsilon used: 0.89)
# Step:15761 | Total games:248 | Mean reward: 1.700  (epsilon used: 0.89)
# Step:15805 | Total games:249 | Mean reward: 1.400  (epsilon used: 0.89)
# Step:15881 | Total games:250 | Mean reward: 1.600  (epsilon used: 0.89)
# Step:15972 | Total games:251 | Mean reward: 1.600  (epsilon used: 0.89)
# Step:16029 | Total games:252 | Mean reward: 1.600  (epsilon used: 0.89)
# Step:16093 | Total games:253 | Mean reward: 1.400  (epsilon used: 0.89)
# Step:16163 | Total games:254 | Mean reward: 1.300  (epsilon used: 0.89)
# Step:16224 | Total games:255 | Mean reward: 1.200  (epsilon used: 0.89)
# Step:16285 | Total games:256 | Mean reward: 1.200  (epsilon used: 0.89)
# Step:16362 | Total games:257 | Mean reward: 1.400  (epsilon used: 0.88)
# Step:16440 | Total games:258 | Mean reward: 1.800  (epsilon used: 0.88)
# Step:16485 | Total games:259 | Mean reward: 1.900  (epsilon used: 0.88)
# Step:16554 | Total games:260 | Mean reward: 1.700  (epsilon used: 0.88)
# Step:16617 | Total games:261 | Mean reward: 1.600  (epsilon used: 0.88)
# Step:16704 | Total games:262 | Mean reward: 1.800  (epsilon used: 0.88)
# Step:16765 | Total games:263 | Mean reward: 1.900  (epsilon used: 0.88)
# Step:16826 | Total games:264 | Mean reward: 1.900  (epsilon used: 0.88)
# Step:16895 | Total games:265 | Mean reward: 2.000  (epsilon used: 0.88)
# Step:16941 | Total games:266 | Mean reward: 1.900  (epsilon used: 0.88)
# Step:17015 | Total games:267 | Mean reward: 1.900  (epsilon used: 0.88)
# Step:17078 | Total games:268 | Mean reward: 1.600  (epsilon used: 0.88)
# Step:17135 | Total games:269 | Mean reward: 1.700  (epsilon used: 0.88)
# Step:17205 | Total games:270 | Mean reward: 1.800  (epsilon used: 0.88)
# Step:17278 | Total games:271 | Mean reward: 2.000  (epsilon used: 0.88)
# Step:17334 | Total games:272 | Mean reward: 1.800  (epsilon used: 0.88)
# Step:17405 | Total games:273 | Mean reward: 1.900  (epsilon used: 0.88)
# Step:17485 | Total games:274 | Mean reward: 2.200  (epsilon used: 0.88)
# Step:17541 | Total games:275 | Mean reward: 2.000  (epsilon used: 0.88)
# Step:17599 | Total games:276 | Mean reward: 2.100  (epsilon used: 0.88)
# Step:17655 | Total games:277 | Mean reward: 2.000  (epsilon used: 0.88)
# Step:17737 | Total games:278 | Mean reward: 2.300  (epsilon used: 0.88)
# Step:17790 | Total games:279 | Mean reward: 2.200  (epsilon used: 0.88)
# Step:17855 | Total games:280 | Mean reward: 2.000  (epsilon used: 0.87)
# Step:17918 | Total games:281 | Mean reward: 1.800  (epsilon used: 0.87)
# Step:17958 | Total games:282 | Mean reward: 1.700  (epsilon used: 0.87)
# Step:18009 | Total games:283 | Mean reward: 1.600  (epsilon used: 0.87)
# Step:18072 | Total games:284 | Mean reward: 1.400  (epsilon used: 0.87)
# Step:18129 | Total games:285 | Mean reward: 1.500  (epsilon used: 0.87)
# Step:18225 | Total games:286 | Mean reward: 1.700  (epsilon used: 0.87)
# Step:18315 | Total games:287 | Mean reward: 1.800  (epsilon used: 0.87)
# Step:18356 | Total games:288 | Mean reward: 1.400  (epsilon used: 0.87)
# Step:18456 | Total games:289 | Mean reward: 1.900  (epsilon used: 0.87)
# Step:18495 | Total games:290 | Mean reward: 1.800  (epsilon used: 0.87)
# Step:18581 | Total games:291 | Mean reward: 1.900  (epsilon used: 0.87)
# Step:18636 | Total games:292 | Mean reward: 2.000  (epsilon used: 0.87)
# Step:18679 | Total games:293 | Mean reward: 1.900  (epsilon used: 0.87)
# Step:18734 | Total games:294 | Mean reward: 1.900  (epsilon used: 0.87)
# Step:18787 | Total games:295 | Mean reward: 1.900  (epsilon used: 0.87)
# Step:18844 | Total games:296 | Mean reward: 1.800  (epsilon used: 0.87)
# Step:18895 | Total games:297 | Mean reward: 1.500  (epsilon used: 0.87)
# Step:18962 | Total games:298 | Mean reward: 1.600  (epsilon used: 0.87)
# Step:19032 | Total games:299 | Mean reward: 1.100  (epsilon used: 0.87)
# Step:19072 | Total games:300 | Mean reward: 1.100  (epsilon used: 0.87)
# Step:19132 | Total games:301 | Mean reward: 1.100  (epsilon used: 0.87)
# Step:19187 | Total games:302 | Mean reward: 1.200  (epsilon used: 0.87)
# Step:19229 | Total games:303 | Mean reward: 1.200  (epsilon used: 0.87)
# Step:19287 | Total games:304 | Mean reward: 1.200  (epsilon used: 0.87)
# Step:19329 | Total games:305 | Mean reward: 1.100  (epsilon used: 0.87)
# Step:19370 | Total games:306 | Mean reward: 0.900  (epsilon used: 0.86)
# Step:19456 | Total games:307 | Mean reward: 1.300  (epsilon used: 0.86)
# Step:19506 | Total games:308 | Mean reward: 1.300  (epsilon used: 0.86)
# Step:19612 | Total games:309 | Mean reward: 1.800  (epsilon used: 0.86)
# Step:19682 | Total games:310 | Mean reward: 1.900  (epsilon used: 0.86)
# Step:19746 | Total games:311 | Mean reward: 1.900  (epsilon used: 0.86)
# Step:19832 | Total games:312 | Mean reward: 1.900  (epsilon used: 0.86)
# Step:19880 | Total games:313 | Mean reward: 2.000  (epsilon used: 0.86)
# Step:19954 | Total games:314 | Mean reward: 2.000  (epsilon used: 0.86)
# Step:20006 | Total games:315 | Mean reward: 2.100  (epsilon used: 0.86)
# Step:20076 | Total games:316 | Mean reward: 2.300  (epsilon used: 0.86)
# Step:20146 | Total games:317 | Mean reward: 2.100  (epsilon used: 0.86)
# Step:20203 | Total games:318 | Mean reward: 2.000  (epsilon used: 0.86)
# Step:20263 | Total games:319 | Mean reward: 1.500  (epsilon used: 0.86)
# Step:20325 | Total games:320 | Mean reward: 1.400  (epsilon used: 0.86)
# Step:20429 | Total games:321 | Mean reward: 1.600  (epsilon used: 0.86)
# Step:20507 | Total games:322 | Mean reward: 1.600  (epsilon used: 0.86)
# Step:20562 | Total games:323 | Mean reward: 1.600  (epsilon used: 0.86)
# Step:20634 | Total games:324 | Mean reward: 1.500  (epsilon used: 0.86)
# Step:20706 | Total games:325 | Mean reward: 1.600  (epsilon used: 0.86)
# Step:20757 | Total games:326 | Mean reward: 1.500  (epsilon used: 0.86)
# Step:20861 | Total games:327 | Mean reward: 1.800  (epsilon used: 0.86)
# Step:20918 | Total games:328 | Mean reward: 1.800  (epsilon used: 0.85)
# Step:21011 | Total games:329 | Mean reward: 2.200  (epsilon used: 0.85)
# Step:21089 | Total games:330 | Mean reward: 2.300  (epsilon used: 0.85)
# Step:21135 | Total games:331 | Mean reward: 1.900  (epsilon used: 0.85)
# Step:21204 | Total games:332 | Mean reward: 2.000  (epsilon used: 0.85)
# Step:21263 | Total games:333 | Mean reward: 2.000  (epsilon used: 0.85)
# Step:21325 | Total games:334 | Mean reward: 2.100  (epsilon used: 0.85)
# Step:21385 | Total games:335 | Mean reward: 2.200  (epsilon used: 0.85)
# Step:21475 | Total games:336 | Mean reward: 2.400  (epsilon used: 0.85)
# Step:21560 | Total games:337 | Mean reward: 2.200  (epsilon used: 0.85)
# Step:21617 | Total games:338 | Mean reward: 2.400  (epsilon used: 0.85)
# Step:21664 | Total games:339 | Mean reward: 2.000  (epsilon used: 0.85)
# Step:21739 | Total games:340 | Mean reward: 2.000  (epsilon used: 0.85)
# Step:21786 | Total games:341 | Mean reward: 2.000  (epsilon used: 0.85)
# Step:21852 | Total games:342 | Mean reward: 1.800  (epsilon used: 0.85)
# Step:21912 | Total games:343 | Mean reward: 1.800  (epsilon used: 0.85)
# Step:21983 | Total games:344 | Mean reward: 1.800  (epsilon used: 0.85)
# Step:22042 | Total games:345 | Mean reward: 1.700  (epsilon used: 0.85)
# Step:22096 | Total games:346 | Mean reward: 1.500  (epsilon used: 0.85)
# Step:22148 | Total games:347 | Mean reward: 1.300  (epsilon used: 0.85)
# Step:22211 | Total games:348 | Mean reward: 1.200  (epsilon used: 0.85)
# Step:22296 | Total games:349 | Mean reward: 1.300  (epsilon used: 0.85)
# Step:22349 | Total games:350 | Mean reward: 1.400  (epsilon used: 0.85)
# Step:22453 | Total games:351 | Mean reward: 1.800  (epsilon used: 0.85)
# Step:22515 | Total games:352 | Mean reward: 2.000  (epsilon used: 0.84)
# Step:22573 | Total games:353 | Mean reward: 2.100  (epsilon used: 0.84)
# Step:22635 | Total games:354 | Mean reward: 1.900  (epsilon used: 0.84)
# Step:22694 | Total games:355 | Mean reward: 1.900  (epsilon used: 0.84)
# Step:22801 | Total games:356 | Mean reward: 2.200  (epsilon used: 0.84)
# Step:22841 | Total games:357 | Mean reward: 2.100  (epsilon used: 0.84)
# Step:22882 | Total games:358 | Mean reward: 2.000  (epsilon used: 0.84)
# Step:22927 | Total games:359 | Mean reward: 1.900  (epsilon used: 0.84)
# Step:22999 | Total games:360 | Mean reward: 1.900  (epsilon used: 0.84)
# Step:23090 | Total games:361 | Mean reward: 1.800  (epsilon used: 0.84)
# Step:23141 | Total games:362 | Mean reward: 1.500  (epsilon used: 0.84)
# Step:23198 | Total games:363 | Mean reward: 1.400  (epsilon used: 0.84)
# Step:23293 | Total games:364 | Mean reward: 1.500  (epsilon used: 0.84)
# Step:23366 | Total games:365 | Mean reward: 1.600  (epsilon used: 0.84)
# Step:23443 | Total games:366 | Mean reward: 1.300  (epsilon used: 0.84)
# Step:23499 | Total games:367 | Mean reward: 1.300  (epsilon used: 0.84)
# Step:23555 | Total games:368 | Mean reward: 1.400  (epsilon used: 0.84)
# Step:23617 | Total games:369 | Mean reward: 1.400  (epsilon used: 0.84)
# Step:23670 | Total games:370 | Mean reward: 1.200  (epsilon used: 0.84)
# Step:23725 | Total games:371 | Mean reward: 0.900  (epsilon used: 0.84)
# Step:23811 | Total games:372 | Mean reward: 1.200  (epsilon used: 0.84)
# Step:23892 | Total games:373 | Mean reward: 1.300  (epsilon used: 0.84)
# Step:23948 | Total games:374 | Mean reward: 1.400  (epsilon used: 0.84)
# Step:24025 | Total games:375 | Mean reward: 1.500  (epsilon used: 0.84)
# Step:24094 | Total games:376 | Mean reward: 1.600  (epsilon used: 0.83)
# Step:24144 | Total games:377 | Mean reward: 1.700  (epsilon used: 0.83)
# Step:24219 | Total games:378 | Mean reward: 1.800  (epsilon used: 0.83)
# Step:24275 | Total games:379 | Mean reward: 1.900  (epsilon used: 0.83)
# Step:24327 | Total games:380 | Mean reward: 2.100  (epsilon used: 0.83)
# Step:24392 | Total games:381 | Mean reward: 2.100  (epsilon used: 0.83)
# Step:24464 | Total games:382 | Mean reward: 2.100  (epsilon used: 0.83)
# Step:24514 | Total games:383 | Mean reward: 1.900  (epsilon used: 0.83)
# Step:24576 | Total games:384 | Mean reward: 1.800  (epsilon used: 0.83)
# Step:24657 | Total games:385 | Mean reward: 1.600  (epsilon used: 0.83)
# Step:24733 | Total games:386 | Mean reward: 1.600  (epsilon used: 0.83)
# Step:24782 | Total games:387 | Mean reward: 1.500  (epsilon used: 0.83)
# Step:24836 | Total games:388 | Mean reward: 1.300  (epsilon used: 0.83)
# Step:24892 | Total games:389 | Mean reward: 1.200  (epsilon used: 0.83)
# Step:24943 | Total games:390 | Mean reward: 1.000  (epsilon used: 0.83)
# Step:25016 | Total games:391 | Mean reward: 1.000  (epsilon used: 0.83)
# Step:25060 | Total games:392 | Mean reward: 0.700  (epsilon used: 0.83)
# Step:25107 | Total games:393 | Mean reward: 0.700  (epsilon used: 0.83)
# Step:25191 | Total games:394 | Mean reward: 0.800  (epsilon used: 0.83)
# Step:25249 | Total games:395 | Mean reward: 0.800  (epsilon used: 0.83)
# Step:25303 | Total games:396 | Mean reward: 0.700  (epsilon used: 0.83)
# Step:25357 | Total games:397 | Mean reward: 0.900  (epsilon used: 0.83)
# Step:25437 | Total games:398 | Mean reward: 1.300  (epsilon used: 0.83)
# Step:25502 | Total games:399 | Mean reward: 1.300  (epsilon used: 0.83)
# Step:25567 | Total games:400 | Mean reward: 1.600  (epsilon used: 0.83)
# Step:25644 | Total games:401 | Mean reward: 1.700  (epsilon used: 0.83)
# Step:25694 | Total games:402 | Mean reward: 1.700  (epsilon used: 0.82)
# Step:25736 | Total games:403 | Mean reward: 1.700  (epsilon used: 0.82)
# Step:25810 | Total games:404 | Mean reward: 1.800  (epsilon used: 0.82)
# Step:25862 | Total games:405 | Mean reward: 1.800  (epsilon used: 0.82)
# Step:25965 | Total games:406 | Mean reward: 2.100  (epsilon used: 0.82)
# Step:26061 | Total games:407 | Mean reward: 2.300  (epsilon used: 0.82)
# Step:26133 | Total games:408 | Mean reward: 2.100  (epsilon used: 0.82)
# Step:26180 | Total games:409 | Mean reward: 2.100  (epsilon used: 0.82)
# Step:26250 | Total games:410 | Mean reward: 2.100  (epsilon used: 0.82)
# Step:26331 | Total games:411 | Mean reward: 2.000  (epsilon used: 0.82)
# Step:26429 | Total games:412 | Mean reward: 2.700  (epsilon used: 0.82)
# Step:26507 | Total games:413 | Mean reward: 3.000  (epsilon used: 0.82)
# Step:26569 | Total games:414 | Mean reward: 2.900  (epsilon used: 0.82)
# Step:26627 | Total games:415 | Mean reward: 2.800  (epsilon used: 0.82)
# Step:26740 | Total games:416 | Mean reward: 2.800  (epsilon used: 0.82)
# Step:26809 | Total games:417 | Mean reward: 2.700  (epsilon used: 0.82)
# Step:26884 | Total games:418 | Mean reward: 2.800  (epsilon used: 0.82)
# Step:26946 | Total games:419 | Mean reward: 2.800  (epsilon used: 0.82)
# Step:27018 | Total games:420 | Mean reward: 2.700  (epsilon used: 0.82)
# Step:27081 | Total games:421 | Mean reward: 2.600  (epsilon used: 0.82)
# Step:27154 | Total games:422 | Mean reward: 2.200  (epsilon used: 0.82)
# Step:27190 | Total games:423 | Mean reward: 1.900  (epsilon used: 0.82)
# Step:27233 | Total games:424 | Mean reward: 1.700  (epsilon used: 0.82)
# Step:27282 | Total games:425 | Mean reward: 1.700  (epsilon used: 0.81)
# Step:27337 | Total games:426 | Mean reward: 1.500  (epsilon used: 0.81)
# Step:27422 | Total games:427 | Mean reward: 1.500  (epsilon used: 0.81)
# Step:27479 | Total games:428 | Mean reward: 1.400  (epsilon used: 0.81)
# Step:27569 | Total games:429 | Mean reward: 1.600  (epsilon used: 0.81)
# Step:27635 | Total games:430 | Mean reward: 1.600  (epsilon used: 0.81)
# Step:27718 | Total games:431 | Mean reward: 1.900  (epsilon used: 0.81)
# Step:27761 | Total games:432 | Mean reward: 1.700  (epsilon used: 0.81)
# Step:27821 | Total games:433 | Mean reward: 1.900  (epsilon used: 0.81)
# Step:27868 | Total games:434 | Mean reward: 2.000  (epsilon used: 0.81)
# Step:27955 | Total games:435 | Mean reward: 2.000  (epsilon used: 0.81)
# Step:28000 | Total games:436 | Mean reward: 1.900  (epsilon used: 0.81)
# Step:28065 | Total games:437 | Mean reward: 1.700  (epsilon used: 0.81)
# Step:28104 | Total games:438 | Mean reward: 1.500  (epsilon used: 0.81)
# Step:28161 | Total games:439 | Mean reward: 1.400  (epsilon used: 0.81)
# Step:28242 | Total games:440 | Mean reward: 1.600  (epsilon used: 0.81)
# Step:28315 | Total games:441 | Mean reward: 1.600  (epsilon used: 0.81)
# Step:28373 | Total games:442 | Mean reward: 1.700  (epsilon used: 0.81)
# Step:28428 | Total games:443 | Mean reward: 1.600  (epsilon used: 0.81)
# Step:28495 | Total games:444 | Mean reward: 1.600  (epsilon used: 0.81)
# Step:28551 | Total games:445 | Mean reward: 1.600  (epsilon used: 0.81)
# Step:28610 | Total games:446 | Mean reward: 1.800  (epsilon used: 0.81)
# Step:28658 | Total games:447 | Mean reward: 1.700  (epsilon used: 0.81)
# Step:28724 | Total games:448 | Mean reward: 1.900  (epsilon used: 0.81)
# Step:28784 | Total games:449 | Mean reward: 1.900  (epsilon used: 0.81)
# Step:28858 | Total games:450 | Mean reward: 1.700  (epsilon used: 0.81)
# Step:28918 | Total games:451 | Mean reward: 1.600  (epsilon used: 0.81)
# Step:28995 | Total games:452 | Mean reward: 1.600  (epsilon used: 0.80)
# Step:29048 | Total games:453 | Mean reward: 1.700  (epsilon used: 0.80)
# Step:29129 | Total games:454 | Mean reward: 1.900  (epsilon used: 0.80)
# Step:29190 | Total games:455 | Mean reward: 1.900  (epsilon used: 0.80)
# Step:29248 | Total games:456 | Mean reward: 1.800  (epsilon used: 0.80)
# Step:29312 | Total games:457 | Mean reward: 1.800  (epsilon used: 0.80)
# Step:29402 | Total games:458 | Mean reward: 1.700  (epsilon used: 0.80)
# Step:29461 | Total games:459 | Mean reward: 1.700  (epsilon used: 0.80)
# Step:29508 | Total games:460 | Mean reward: 1.600  (epsilon used: 0.80)
# Step:29594 | Total games:461 | Mean reward: 1.500  (epsilon used: 0.80)
# Step:29703 | Total games:462 | Mean reward: 1.900  (epsilon used: 0.80)
# Step:29768 | Total games:463 | Mean reward: 1.700  (epsilon used: 0.80)
# Step:29825 | Total games:464 | Mean reward: 1.600  (epsilon used: 0.80)
# Step:29893 | Total games:465 | Mean reward: 1.800  (epsilon used: 0.80)
# Step:29962 | Total games:466 | Mean reward: 1.800  (epsilon used: 0.80)
# Step:30036 | Total games:467 | Mean reward: 2.100  (epsilon used: 0.80)
# Step:30088 | Total games:468 | Mean reward: 2.100  (epsilon used: 0.80)
# Step:30145 | Total games:469 | Mean reward: 1.900  (epsilon used: 0.80)
# Step:30199 | Total games:470 | Mean reward: 1.800  (epsilon used: 0.80)
# Step:30256 | Total games:471 | Mean reward: 1.800  (epsilon used: 0.80)
# Step:30327 | Total games:472 | Mean reward: 1.400  (epsilon used: 0.80)
# Step:30374 | Total games:473 | Mean reward: 1.400  (epsilon used: 0.80)
# Step:30431 | Total games:474 | Mean reward: 1.400  (epsilon used: 0.80)
# Step:30488 | Total games:475 | Mean reward: 1.300  (epsilon used: 0.80)
# Step:30561 | Total games:476 | Mean reward: 1.200  (epsilon used: 0.80)
# Step:30610 | Total games:477 | Mean reward: 1.000  (epsilon used: 0.79)
# Step:30656 | Total games:478 | Mean reward: 0.900  (epsilon used: 0.79)
# Step:30720 | Total games:479 | Mean reward: 1.100  (epsilon used: 0.79)
# Step:30768 | Total games:480 | Mean reward: 1.200  (epsilon used: 0.79)
# Step:30841 | Total games:481 | Mean reward: 1.200  (epsilon used: 0.79)
# Step:30914 | Total games:482 | Mean reward: 1.200  (epsilon used: 0.79)
# Step:30982 | Total games:483 | Mean reward: 1.400  (epsilon used: 0.79)
# Step:31040 | Total games:484 | Mean reward: 1.300  (epsilon used: 0.79)
# Step:31099 | Total games:485 | Mean reward: 1.200  (epsilon used: 0.79)
# Step:31178 | Total games:486 | Mean reward: 1.400  (epsilon used: 0.79)
# Step:31240 | Total games:487 | Mean reward: 1.500  (epsilon used: 0.79)
# Step:31307 | Total games:488 | Mean reward: 1.800  (epsilon used: 0.79)
# Step:31354 | Total games:489 | Mean reward: 1.600  (epsilon used: 0.79)
# Step:31417 | Total games:490 | Mean reward: 1.700  (epsilon used: 0.79)
# Step:31478 | Total games:491 | Mean reward: 1.900  (epsilon used: 0.79)
# Step:31553 | Total games:492 | Mean reward: 2.100  (epsilon used: 0.79)
# Step:31597 | Total games:493 | Mean reward: 2.000  (epsilon used: 0.79)
# Step:31658 | Total games:494 | Mean reward: 2.000  (epsilon used: 0.79)
# Step:31726 | Total games:495 | Mean reward: 2.300  (epsilon used: 0.79)
# Step:31815 | Total games:496 | Mean reward: 2.400  (epsilon used: 0.79)
# Step:31885 | Total games:497 | Mean reward: 2.400  (epsilon used: 0.79)
# Step:31952 | Total games:498 | Mean reward: 2.200  (epsilon used: 0.79)
# Step:32023 | Total games:499 | Mean reward: 2.400  (epsilon used: 0.79)
# Step:32070 | Total games:500 | Mean reward: 2.300  (epsilon used: 0.79)
# Step:32133 | Total games:501 | Mean reward: 2.200  (epsilon used: 0.79)
# Step:32194 | Total games:502 | Mean reward: 1.900  (epsilon used: 0.79)
# Step:32250 | Total games:503 | Mean reward: 2.000  (epsilon used: 0.79)
# Step:32334 | Total games:504 | Mean reward: 2.000  (epsilon used: 0.78)
# Step:32375 | Total games:505 | Mean reward: 1.600  (epsilon used: 0.78)
# Step:32441 | Total games:506 | Mean reward: 1.300  (epsilon used: 0.78)
# Step:32540 | Total games:507 | Mean reward: 1.300  (epsilon used: 0.78)
# Step:32597 | Total games:508 | Mean reward: 1.200  (epsilon used: 0.78)
# Step:32683 | Total games:509 | Mean reward: 1.400  (epsilon used: 0.78)
# Step:32734 | Total games:510 | Mean reward: 1.300  (epsilon used: 0.78)
# Step:32805 | Total games:511 | Mean reward: 1.300  (epsilon used: 0.78)
# Step:32882 | Total games:512 | Mean reward: 1.400  (epsilon used: 0.78)
# Step:32931 | Total games:513 | Mean reward: 1.300  (epsilon used: 0.78)
# Step:32987 | Total games:514 | Mean reward: 1.400  (epsilon used: 0.78)
# Step:33058 | Total games:515 | Mean reward: 1.700  (epsilon used: 0.78)
# Step:33118 | Total games:516 | Mean reward: 1.600  (epsilon used: 0.78)
# Step:33200 | Total games:517 | Mean reward: 1.800  (epsilon used: 0.78)
# Step:33283 | Total games:518 | Mean reward: 1.900  (epsilon used: 0.78)
# Step:33355 | Total games:519 | Mean reward: 1.600  (epsilon used: 0.78)
# Step:33431 | Total games:520 | Mean reward: 1.900  (epsilon used: 0.78)
# Step:33504 | Total games:521 | Mean reward: 1.900  (epsilon used: 0.78)
# Step:33582 | Total games:522 | Mean reward: 1.900  (epsilon used: 0.78)
# Step:33650 | Total games:523 | Mean reward: 2.100  (epsilon used: 0.78)
# Step:33708 | Total games:524 | Mean reward: 2.100  (epsilon used: 0.78)
# Step:33784 | Total games:525 | Mean reward: 1.900  (epsilon used: 0.78)
# Step:33838 | Total games:526 | Mean reward: 2.100  (epsilon used: 0.78)
# Step:33913 | Total games:527 | Mean reward: 1.800  (epsilon used: 0.78)
# Step:33988 | Total games:528 | Mean reward: 2.000  (epsilon used: 0.77)
# Step:34042 | Total games:529 | Mean reward: 2.000  (epsilon used: 0.77)
# Step:34098 | Total games:530 | Mean reward: 1.700  (epsilon used: 0.77)
# Step:34182 | Total games:531 | Mean reward: 1.900  (epsilon used: 0.77)
# Step:34234 | Total games:532 | Mean reward: 1.900  (epsilon used: 0.77)
# Step:34296 | Total games:533 | Mean reward: 1.800  (epsilon used: 0.77)
# Step:34393 | Total games:534 | Mean reward: 2.000  (epsilon used: 0.77)
# Step:34480 | Total games:535 | Mean reward: 2.100  (epsilon used: 0.77)
# Step:34540 | Total games:536 | Mean reward: 2.000  (epsilon used: 0.77)
# Step:34626 | Total games:537 | Mean reward: 2.700  (epsilon used: 0.77)
# Step:34705 | Total games:538 | Mean reward: 2.700  (epsilon used: 0.77)
# Step:34787 | Total games:539 | Mean reward: 2.800  (epsilon used: 0.77)
# Step:34838 | Total games:540 | Mean reward: 2.800  (epsilon used: 0.77)
# Step:34924 | Total games:541 | Mean reward: 2.700  (epsilon used: 0.77)
# Step:34976 | Total games:542 | Mean reward: 2.600  (epsilon used: 0.77)
# Step:35028 | Total games:543 | Mean reward: 2.400  (epsilon used: 0.77)
# Step:35079 | Total games:544 | Mean reward: 2.000  (epsilon used: 0.77)
# Step:35133 | Total games:545 | Mean reward: 1.900  (epsilon used: 0.77)
# Step:35176 | Total games:546 | Mean reward: 1.800  (epsilon used: 0.77)
# Step:35227 | Total games:547 | Mean reward: 1.100  (epsilon used: 0.77)
# Step:35283 | Total games:548 | Mean reward: 1.000  (epsilon used: 0.77)
# Step:35357 | Total games:549 | Mean reward: 0.800  (epsilon used: 0.77)
# Step:35438 | Total games:550 | Mean reward: 1.000  (epsilon used: 0.77)
# Step:35479 | Total games:551 | Mean reward: 0.800  (epsilon used: 0.77)
# Step:35540 | Total games:552 | Mean reward: 0.900  (epsilon used: 0.77)
# Step:35625 | Total games:553 | Mean reward: 1.200  (epsilon used: 0.77)
# Step:35680 | Total games:554 | Mean reward: 1.300  (epsilon used: 0.77)
# Step:35759 | Total games:555 | Mean reward: 1.300  (epsilon used: 0.76)
# Step:35839 | Total games:556 | Mean reward: 1.400  (epsilon used: 0.76)
# Step:35936 | Total games:557 | Mean reward: 1.700  (epsilon used: 0.76)
# Step:35990 | Total games:558 | Mean reward: 1.700  (epsilon used: 0.76)
# Step:36080 | Total games:559 | Mean reward: 2.000  (epsilon used: 0.76)
# Step:36149 | Total games:560 | Mean reward: 2.000  (epsilon used: 0.76)
# Step:36214 | Total games:561 | Mean reward: 2.000  (epsilon used: 0.76)
# Step:36278 | Total games:562 | Mean reward: 2.100  (epsilon used: 0.76)
# Step:36359 | Total games:563 | Mean reward: 2.100  (epsilon used: 0.76)
# Step:36452 | Total games:564 | Mean reward: 2.400  (epsilon used: 0.76)
# Step:36544 | Total games:565 | Mean reward: 2.800  (epsilon used: 0.76)
# Step:36615 | Total games:566 | Mean reward: 3.000  (epsilon used: 0.76)
# Step:36670 | Total games:567 | Mean reward: 2.600  (epsilon used: 0.76)
# Step:36736 | Total games:568 | Mean reward: 2.500  (epsilon used: 0.76)
# Step:36784 | Total games:569 | Mean reward: 2.300  (epsilon used: 0.76)
# Step:36833 | Total games:570 | Mean reward: 2.200  (epsilon used: 0.76)
# Step:36889 | Total games:571 | Mean reward: 2.200  (epsilon used: 0.76)
# Step:36950 | Total games:572 | Mean reward: 2.000  (epsilon used: 0.76)
# Step:37010 | Total games:573 | Mean reward: 1.900  (epsilon used: 0.76)
# Step:37108 | Total games:574 | Mean reward: 1.900  (epsilon used: 0.76)
# Step:37193 | Total games:575 | Mean reward: 1.700  (epsilon used: 0.76)
# Step:37267 | Total games:576 | Mean reward: 1.700  (epsilon used: 0.76)
# Step:37333 | Total games:577 | Mean reward: 1.800  (epsilon used: 0.76)
# Step:37419 | Total games:578 | Mean reward: 2.000  (epsilon used: 0.76)
# Step:37488 | Total games:579 | Mean reward: 2.100  (epsilon used: 0.75)
# Step:37566 | Total games:580 | Mean reward: 2.200  (epsilon used: 0.75)
# Step:37677 | Total games:581 | Mean reward: 2.400  (epsilon used: 0.75)
# Step:37736 | Total games:582 | Mean reward: 2.500  (epsilon used: 0.75)
# Step:37786 | Total games:583 | Mean reward: 2.400  (epsilon used: 0.75)
# Step:37856 | Total games:584 | Mean reward: 2.100  (epsilon used: 0.75)
# Step:37922 | Total games:585 | Mean reward: 2.100  (epsilon used: 0.75)
# Step:37979 | Total games:586 | Mean reward: 2.000  (epsilon used: 0.75)
# Step:38051 | Total games:587 | Mean reward: 2.100  (epsilon used: 0.75)
# Step:38104 | Total games:588 | Mean reward: 2.000  (epsilon used: 0.75)
# Step:38169 | Total games:589 | Mean reward: 2.000  (epsilon used: 0.75)
# Step:38227 | Total games:590 | Mean reward: 2.000  (epsilon used: 0.75)
# Step:38308 | Total games:591 | Mean reward: 2.100  (epsilon used: 0.75)
# Step:38377 | Total games:592 | Mean reward: 2.100  (epsilon used: 0.75)
# Step:38426 | Total games:593 | Mean reward: 2.100  (epsilon used: 0.75)
# Step:38490 | Total games:594 | Mean reward: 2.300  (epsilon used: 0.75)
# Step:38587 | Total games:595 | Mean reward: 2.500  (epsilon used: 0.75)
# Step:38668 | Total games:596 | Mean reward: 2.600  (epsilon used: 0.75)
# Step:38747 | Total games:597 | Mean reward: 2.700  (epsilon used: 0.75)
# Step:38822 | Total games:598 | Mean reward: 2.900  (epsilon used: 0.75)
# Step:38889 | Total games:599 | Mean reward: 2.800  (epsilon used: 0.75)
# Step:38953 | Total games:600 | Mean reward: 2.800  (epsilon used: 0.75)
# Step:39001 | Total games:601 | Mean reward: 2.400  (epsilon used: 0.75)
# Step:39063 | Total games:602 | Mean reward: 2.300  (epsilon used: 0.75)
# Step:39124 | Total games:603 | Mean reward: 2.300  (epsilon used: 0.75)
# Step:39200 | Total games:604 | Mean reward: 2.000  (epsilon used: 0.75)
# Step:39285 | Total games:605 | Mean reward: 1.900  (epsilon used: 0.74)
# Step:39339 | Total games:606 | Mean reward: 1.700  (epsilon used: 0.74)
# Step:39406 | Total games:607 | Mean reward: 1.500  (epsilon used: 0.74)
# Step:39460 | Total games:608 | Mean reward: 1.100  (epsilon used: 0.74)
# Step:39521 | Total games:609 | Mean reward: 1.100  (epsilon used: 0.74)
# Step:39583 | Total games:610 | Mean reward: 1.200  (epsilon used: 0.74)
# Step:39652 | Total games:611 | Mean reward: 1.400  (epsilon used: 0.74)
# Step:39724 | Total games:612 | Mean reward: 1.500  (epsilon used: 0.74)
# Step:39777 | Total games:613 | Mean reward: 1.500  (epsilon used: 0.74)
# Step:39836 | Total games:614 | Mean reward: 1.600  (epsilon used: 0.74)
# Step:39917 | Total games:615 | Mean reward: 1.600  (epsilon used: 0.74)
# Step:39988 | Total games:616 | Mean reward: 1.700  (epsilon used: 0.74)
# Step:40071 | Total games:617 | Mean reward: 1.800  (epsilon used: 0.74)
# Step:40165 | Total games:618 | Mean reward: 2.200  (epsilon used: 0.74)
# Step:40243 | Total games:619 | Mean reward: 2.500  (epsilon used: 0.74)
# Step:40322 | Total games:620 | Mean reward: 2.600  (epsilon used: 0.74)
# Step:40377 | Total games:621 | Mean reward: 2.400  (epsilon used: 0.74)
# Step:40438 | Total games:622 | Mean reward: 2.400  (epsilon used: 0.74)
# Step:40509 | Total games:623 | Mean reward: 2.700  (epsilon used: 0.74)
# Step:40570 | Total games:624 | Mean reward: 2.700  (epsilon used: 0.74)
# Step:40639 | Total games:625 | Mean reward: 2.300  (epsilon used: 0.74)
# Step:40705 | Total games:626 | Mean reward: 2.300  (epsilon used: 0.74)
# Step:40769 | Total games:627 | Mean reward: 2.100  (epsilon used: 0.74)
# Step:40819 | Total games:628 | Mean reward: 1.900  (epsilon used: 0.74)
# Step:40921 | Total games:629 | Mean reward: 2.000  (epsilon used: 0.74)
# Step:40986 | Total games:630 | Mean reward: 1.600  (epsilon used: 0.74)
# Step:41052 | Total games:631 | Mean reward: 1.800  (epsilon used: 0.73)
# Step:41116 | Total games:632 | Mean reward: 1.900  (epsilon used: 0.73)
# Step:41181 | Total games:633 | Mean reward: 1.700  (epsilon used: 0.73)
# Step:41244 | Total games:634 | Mean reward: 1.600  (epsilon used: 0.73)
# Step:41318 | Total games:635 | Mean reward: 1.800  (epsilon used: 0.73)
# Step:41408 | Total games:636 | Mean reward: 2.100  (epsilon used: 0.73)
# Step:41494 | Total games:637 | Mean reward: 2.500  (epsilon used: 0.73)
# Step:41586 | Total games:638 | Mean reward: 2.500  (epsilon used: 0.73)
# Step:41630 | Total games:639 | Mean reward: 2.000  (epsilon used: 0.73)
# Step:41687 | Total games:640 | Mean reward: 2.100  (epsilon used: 0.73)
# Step:41799 | Total games:641 | Mean reward: 2.600  (epsilon used: 0.73)
# Step:41872 | Total games:642 | Mean reward: 2.500  (epsilon used: 0.73)
# Step:41964 | Total games:643 | Mean reward: 2.500  (epsilon used: 0.73)
# Step:42017 | Total games:644 | Mean reward: 2.600  (epsilon used: 0.73)
# Step:42086 | Total games:645 | Mean reward: 2.400  (epsilon used: 0.73)
# Step:42152 | Total games:646 | Mean reward: 2.000  (epsilon used: 0.73)
# Step:42208 | Total games:647 | Mean reward: 1.700  (epsilon used: 0.73)
# Step:42257 | Total games:648 | Mean reward: 1.600  (epsilon used: 0.73)
# Step:42308 | Total games:649 | Mean reward: 1.600  (epsilon used: 0.73)
# Step:42372 | Total games:650 | Mean reward: 1.600  (epsilon used: 0.73)
# Step:42477 | Total games:651 | Mean reward: 1.500  (epsilon used: 0.73)
# Step:42567 | Total games:652 | Mean reward: 1.800  (epsilon used: 0.73)
# Step:42642 | Total games:653 | Mean reward: 1.900  (epsilon used: 0.73)
# Step:42723 | Total games:654 | Mean reward: 1.900  (epsilon used: 0.73)
# Step:42782 | Total games:655 | Mean reward: 1.900  (epsilon used: 0.73)
# Step:42868 | Total games:656 | Mean reward: 2.100  (epsilon used: 0.73)
# Step:42925 | Total games:657 | Mean reward: 2.200  (epsilon used: 0.72)
# Step:42976 | Total games:658 | Mean reward: 2.200  (epsilon used: 0.72)
# Step:43044 | Total games:659 | Mean reward: 2.400  (epsilon used: 0.72)
# Step:43120 | Total games:660 | Mean reward: 2.300  (epsilon used: 0.72)
# Step:43185 | Total games:661 | Mean reward: 1.800  (epsilon used: 0.72)
# Step:43224 | Total games:662 | Mean reward: 1.300  (epsilon used: 0.72)
# Step:43315 | Total games:663 | Mean reward: 1.500  (epsilon used: 0.72)
# Step:43372 | Total games:664 | Mean reward: 1.400  (epsilon used: 0.72)
# Step:43464 | Total games:665 | Mean reward: 1.500  (epsilon used: 0.72)
# Step:43532 | Total games:666 | Mean reward: 1.400  (epsilon used: 0.72)
# Step:43588 | Total games:667 | Mean reward: 1.400  (epsilon used: 0.72)
# Step:43654 | Total games:668 | Mean reward: 1.500  (epsilon used: 0.72)
# Step:43730 | Total games:669 | Mean reward: 1.500  (epsilon used: 0.72)
# Step:43804 | Total games:670 | Mean reward: 1.600  (epsilon used: 0.72)
# ...
# Step:89393 | Total games:1271 | Mean reward: 6.400  (epsilon used: 0.51)
# Step:89510 | Total games:1272 | Mean reward: 7.100  (epsilon used: 0.51)
# Step:89563 | Total games:1273 | Mean reward: 5.800  (epsilon used: 0.51)
# Step:89648 | Total games:1274 | Mean reward: 5.900  (epsilon used: 0.51)
# Step:89719 | Total games:1275 | Mean reward: 5.300  (epsilon used: 0.51)
# Step:89811 | Total games:1276 | Mean reward: 5.300  (epsilon used: 0.51)
# Step:89894 | Total games:1277 | Mean reward: 5.000  (epsilon used: 0.51)
# Step:89977 | Total games:1278 | Mean reward: 5.200  (epsilon used: 0.51)
# Step:90058 | Total games:1279 | Mean reward: 5.400  (epsilon used: 0.51)
# Step:90143 | Total games:1280 | Mean reward: 5.400  (epsilon used: 0.51)
# Step:90229 | Total games:1281 | Mean reward: 5.400  (epsilon used: 0.51)
# Step:90316 | Total games:1282 | Mean reward: 5.400  (epsilon used: 0.51)
# Step:90399 | Total games:1283 | Mean reward: 5.700  (epsilon used: 0.51)
# Step:90475 | Total games:1284 | Mean reward: 5.600  (epsilon used: 0.51)
# Step:90550 | Total games:1285 | Mean reward: 5.700  (epsilon used: 0.51)
# Step:90637 | Total games:1286 | Mean reward: 5.700  (epsilon used: 0.51)
# Step:90743 | Total games:1287 | Mean reward: 5.800  (epsilon used: 0.51)
# Step:90826 | Total games:1288 | Mean reward: 5.700  (epsilon used: 0.51)
# Step:90877 | Total games:1289 | Mean reward: 5.400  (epsilon used: 0.51)
# Step:90945 | Total games:1290 | Mean reward: 5.200  (epsilon used: 0.51)
# Step:91038 | Total games:1291 | Mean reward: 5.300  (epsilon used: 0.51)
# Step:91116 | Total games:1292 | Mean reward: 4.700  (epsilon used: 0.50)
# Step:91182 | Total games:1293 | Mean reward: 4.600  (epsilon used: 0.50)
# Step:91262 | Total games:1294 | Mean reward: 4.500  (epsilon used: 0.50)
# Step:91347 | Total games:1295 | Mean reward: 4.300  (epsilon used: 0.50)
# Step:91423 | Total games:1296 | Mean reward: 4.100  (epsilon used: 0.50)
# Step:91523 | Total games:1297 | Mean reward: 4.300  (epsilon used: 0.50)
# Step:91599 | Total games:1298 | Mean reward: 4.200  (epsilon used: 0.50)
# Step:91676 | Total games:1299 | Mean reward: 4.800  (epsilon used: 0.50)
# Step:91742 | Total games:1300 | Mean reward: 4.700  (epsilon used: 0.50)
# Step:91836 | Total games:1301 | Mean reward: 4.700  (epsilon used: 0.50)
# Step:91945 | Total games:1302 | Mean reward: 5.200  (epsilon used: 0.50)
# Step:92003 | Total games:1303 | Mean reward: 5.000  (epsilon used: 0.50)
# Step:92133 | Total games:1304 | Mean reward: 5.600  (epsilon used: 0.50)
# Step:92227 | Total games:1305 | Mean reward: 5.900  (epsilon used: 0.50)
# Step:92288 | Total games:1306 | Mean reward: 5.800  (epsilon used: 0.50)
# Step:92411 | Total games:1307 | Mean reward: 5.900  (epsilon used: 0.50)
# Step:92461 | Total games:1308 | Mean reward: 5.700  (epsilon used: 0.50)
# Step:92521 | Total games:1309 | Mean reward: 5.200  (epsilon used: 0.50)
# Step:92612 | Total games:1310 | Mean reward: 5.500  (epsilon used: 0.50)
# Step:92725 | Total games:1311 | Mean reward: 5.600  (epsilon used: 0.50)
# Step:92808 | Total games:1312 | Mean reward: 5.300  (epsilon used: 0.50)
# Step:92895 | Total games:1313 | Mean reward: 5.700  (epsilon used: 0.50)
# Step:92997 | Total games:1314 | Mean reward: 5.500  (epsilon used: 0.50)
# Step:93089 | Total games:1315 | Mean reward: 5.800  (epsilon used: 0.50)
# Step:93130 | Total games:1316 | Mean reward: 5.600  (epsilon used: 0.50)
# Step:93228 | Total games:1317 | Mean reward: 6.000  (epsilon used: 0.50)
# Step:93326 | Total games:1318 | Mean reward: 6.700  (epsilon used: 0.50)
# Step:93426 | Total games:1319 | Mean reward: 7.100  (epsilon used: 0.50)
# Step:93504 | Total games:1320 | Mean reward: 7.300  (epsilon used: 0.50)
# Step:93591 | Total games:1321 | Mean reward: 7.100  (epsilon used: 0.50)
# Step:93631 | Total games:1322 | Mean reward: 6.700  (epsilon used: 0.50)
# Step:93687 | Total games:1323 | Mean reward: 6.400  (epsilon used: 0.50)
# Step:93770 | Total games:1324 | Mean reward: 6.100  (epsilon used: 0.49)
# Step:93848 | Total games:1325 | Mean reward: 5.700  (epsilon used: 0.49)
# Step:93967 | Total games:1326 | Mean reward: 6.400  (epsilon used: 0.49)
# Step:94056 | Total games:1327 | Mean reward: 5.700  (epsilon used: 0.49)
# Step:94157 | Total games:1328 | Mean reward: 5.500  (epsilon used: 0.49)
# Step:94205 | Total games:1329 | Mean reward: 5.000  (epsilon used: 0.49)
# Step:94319 | Total games:1330 | Mean reward: 5.100  (epsilon used: 0.49)
# Step:94385 | Total games:1331 | Mean reward: 5.000  (epsilon used: 0.49)
# Step:94478 | Total games:1332 | Mean reward: 5.900  (epsilon used: 0.49)
# Step:94559 | Total games:1333 | Mean reward: 6.100  (epsilon used: 0.49)
# Step:94634 | Total games:1334 | Mean reward: 6.400  (epsilon used: 0.49)
# Step:94750 | Total games:1335 | Mean reward: 6.700  (epsilon used: 0.49)
# Step:94874 | Total games:1336 | Mean reward: 6.800  (epsilon used: 0.49)
# Step:94939 | Total games:1337 | Mean reward: 6.500  (epsilon used: 0.49)
# Step:95036 | Total games:1338 | Mean reward: 6.400  (epsilon used: 0.49)
# Step:95162 | Total games:1339 | Mean reward: 7.200  (epsilon used: 0.49)
# Step:95246 | Total games:1340 | Mean reward: 6.800  (epsilon used: 0.49)
# Step:95344 | Total games:1341 | Mean reward: 7.000  (epsilon used: 0.49)
# Step:95464 | Total games:1342 | Mean reward: 6.900  (epsilon used: 0.49)
# Step:95524 | Total games:1343 | Mean reward: 6.700  (epsilon used: 0.49)
# Step:95595 | Total games:1344 | Mean reward: 6.300  (epsilon used: 0.49)
# Step:95685 | Total games:1345 | Mean reward: 6.000  (epsilon used: 0.49)
# Step:95736 | Total games:1346 | Mean reward: 5.300  (epsilon used: 0.49)
# Step:95836 | Total games:1347 | Mean reward: 5.700  (epsilon used: 0.49)
# Step:95881 | Total games:1348 | Mean reward: 5.200  (epsilon used: 0.49)
# Step:95931 | Total games:1349 | Mean reward: 4.300  (epsilon used: 0.49)
# Step:96049 | Total games:1350 | Mean reward: 4.600  (epsilon used: 0.49)
# Step:96146 | Total games:1351 | Mean reward: 4.700  (epsilon used: 0.49)
# Step:96251 | Total games:1352 | Mean reward: 4.500  (epsilon used: 0.49)
# Step:96372 | Total games:1353 | Mean reward: 5.100  (epsilon used: 0.49)
# Step:96483 | Total games:1354 | Mean reward: 5.500  (epsilon used: 0.48)
# Step:96604 | Total games:1355 | Mean reward: 5.900  (epsilon used: 0.48)
# Step:96726 | Total games:1356 | Mean reward: 6.600  (epsilon used: 0.48)
# Step:96807 | Total games:1357 | Mean reward: 6.300  (epsilon used: 0.48)
# Step:96930 | Total games:1358 | Mean reward: 7.100  (epsilon used: 0.48)
# Step:97006 | Total games:1359 | Mean reward: 7.800  (epsilon used: 0.48)
# Step:97066 | Total games:1360 | Mean reward: 7.300  (epsilon used: 0.48)
# Step:97200 | Total games:1361 | Mean reward: 7.600  (epsilon used: 0.48)
# Step:97264 | Total games:1362 | Mean reward: 7.200  (epsilon used: 0.48)
# Step:97372 | Total games:1363 | Mean reward: 7.100  (epsilon used: 0.48)
# Step:97471 | Total games:1364 | Mean reward: 7.000  (epsilon used: 0.48)
# Step:97541 | Total games:1365 | Mean reward: 6.500  (epsilon used: 0.48)
# Step:97644 | Total games:1366 | Mean reward: 6.400  (epsilon used: 0.48)
# Step:97744 | Total games:1367 | Mean reward: 6.700  (epsilon used: 0.48)
# Step:97817 | Total games:1368 | Mean reward: 6.200  (epsilon used: 0.48)
# Step:97868 | Total games:1369 | Mean reward: 5.600  (epsilon used: 0.48)
# Step:97943 | Total games:1370 | Mean reward: 5.700  (epsilon used: 0.48)
# Step:98034 | Total games:1371 | Mean reward: 5.300  (epsilon used: 0.48)
# Step:98106 | Total games:1372 | Mean reward: 5.800  (epsilon used: 0.48)
# Step:98162 | Total games:1373 | Mean reward: 5.200  (epsilon used: 0.48)
# Step:98242 | Total games:1374 | Mean reward: 5.000  (epsilon used: 0.48)
# Step:98301 | Total games:1375 | Mean reward: 4.900  (epsilon used: 0.48)
# Step:98362 | Total games:1376 | Mean reward: 4.400  (epsilon used: 0.48)
# Step:98420 | Total games:1377 | Mean reward: 3.900  (epsilon used: 0.48)
# Step:98519 | Total games:1378 | Mean reward: 4.200  (epsilon used: 0.48)
# Step:98579 | Total games:1379 | Mean reward: 4.300  (epsilon used: 0.48)
# Step:98707 | Total games:1380 | Mean reward: 5.200  (epsilon used: 0.48)
# Step:98769 | Total games:1381 | Mean reward: 4.900  (epsilon used: 0.48)
# Step:98828 | Total games:1382 | Mean reward: 4.400  (epsilon used: 0.48)
# Step:98919 | Total games:1383 | Mean reward: 4.800  (epsilon used: 0.48)
# Step:99042 | Total games:1384 | Mean reward: 5.600  (epsilon used: 0.48)
# Step:99104 | Total games:1385 | Mean reward: 5.600  (epsilon used: 0.48)
# Step:99195 | Total games:1386 | Mean reward: 5.900  (epsilon used: 0.48)
# Step:99276 | Total games:1387 | Mean reward: 6.200  (epsilon used: 0.47)
# Step:99340 | Total games:1388 | Mean reward: 5.900  (epsilon used: 0.47)
# Step:99460 | Total games:1389 | Mean reward: 6.500  (epsilon used: 0.47)
# Step:99540 | Total games:1390 | Mean reward: 5.700  (epsilon used: 0.47)
# Step:99661 | Total games:1391 | Mean reward: 6.300  (epsilon used: 0.47)
# Step:99766 | Total games:1392 | Mean reward: 6.800  (epsilon used: 0.47)
# Step:99851 | Total games:1393 | Mean reward: 6.700  (epsilon used: 0.47)
# Step:99934 | Total games:1394 | Mean reward: 6.000  (epsilon used: 0.47)
# Step:100017 | Total games:1395 | Mean reward: 6.200  (epsilon used: 0.47)
# Step:100088 | Total games:1396 | Mean reward: 6.000  (epsilon used: 0.47)
# Step:100207 | Total games:1397 | Mean reward: 6.300  (epsilon used: 0.47)
# Step:100286 | Total games:1398 | Mean reward: 6.300  (epsilon used: 0.47)
# Step:100353 | Total games:1399 | Mean reward: 5.800  (epsilon used: 0.47)
# Step:100415 | Total games:1400 | Mean reward: 5.600  (epsilon used: 0.47)
# Step:100500 | Total games:1401 | Mean reward: 5.300  (epsilon used: 0.47)
# Step:100608 | Total games:1402 | Mean reward: 5.300  (epsilon used: 0.47)
# Step:100716 | Total games:1403 | Mean reward: 5.500  (epsilon used: 0.47)
# Step:100777 | Total games:1404 | Mean reward: 5.200  (epsilon used: 0.47)
# Step:100875 | Total games:1405 | Mean reward: 5.400  (epsilon used: 0.47)
# Step:100954 | Total games:1406 | Mean reward: 5.500  (epsilon used: 0.47)
# Step:101047 | Total games:1407 | Mean reward: 5.300  (epsilon used: 0.47)
# Step:101139 | Total games:1408 | Mean reward: 5.500  (epsilon used: 0.47)
# Step:101247 | Total games:1409 | Mean reward: 5.800  (epsilon used: 0.47)
# Step:101327 | Total games:1410 | Mean reward: 6.000  (epsilon used: 0.47)
# Step:101376 | Total games:1411 | Mean reward: 5.600  (epsilon used: 0.47)
# Step:101484 | Total games:1412 | Mean reward: 5.600  (epsilon used: 0.47)
# Step:101598 | Total games:1413 | Mean reward: 5.700  (epsilon used: 0.47)
# Step:101711 | Total games:1414 | Mean reward: 6.100  (epsilon used: 0.47)
# Step:101793 | Total games:1415 | Mean reward: 6.000  (epsilon used: 0.47)
# Step:101901 | Total games:1416 | Mean reward: 6.200  (epsilon used: 0.47)
# Step:101987 | Total games:1417 | Mean reward: 6.200  (epsilon used: 0.47)
# Step:102059 | Total games:1418 | Mean reward: 6.000  (epsilon used: 0.47)
# Step:102182 | Total games:1419 | Mean reward: 6.300  (epsilon used: 0.46)
# Step:102276 | Total games:1420 | Mean reward: 6.400  (epsilon used: 0.46)
# Step:102338 | Total games:1421 | Mean reward: 6.500  (epsilon used: 0.46)
# Step:102402 | Total games:1422 | Mean reward: 6.000  (epsilon used: 0.46)
# Step:102471 | Total games:1423 | Mean reward: 5.500  (epsilon used: 0.46)
# Step:102568 | Total games:1424 | Mean reward: 5.400  (epsilon used: 0.46)
# Step:102619 | Total games:1425 | Mean reward: 5.000  (epsilon used: 0.46)
# Step:102668 | Total games:1426 | Mean reward: 4.400  (epsilon used: 0.46)
# Step:102762 | Total games:1427 | Mean reward: 4.300  (epsilon used: 0.46)
# Step:102822 | Total games:1428 | Mean reward: 4.200  (epsilon used: 0.46)
# Step:102921 | Total games:1429 | Mean reward: 3.900  (epsilon used: 0.46)
# Step:103016 | Total games:1430 | Mean reward: 4.000  (epsilon used: 0.46)
# Step:103105 | Total games:1431 | Mean reward: 4.300  (epsilon used: 0.46)
# Step:103173 | Total games:1432 | Mean reward: 4.400  (epsilon used: 0.46)
# Step:103272 | Total games:1433 | Mean reward: 4.700  (epsilon used: 0.46)
# Step:103356 | Total games:1434 | Mean reward: 5.000  (epsilon used: 0.46)
# Step:103435 | Total games:1435 | Mean reward: 5.200  (epsilon used: 0.46)
# Step:103513 | Total games:1436 | Mean reward: 5.600  (epsilon used: 0.46)
# Step:103582 | Total games:1437 | Mean reward: 5.500  (epsilon used: 0.46)
# Step:103669 | Total games:1438 | Mean reward: 5.700  (epsilon used: 0.46)
# Step:103740 | Total games:1439 | Mean reward: 5.400  (epsilon used: 0.46)
# Step:103810 | Total games:1440 | Mean reward: 5.000  (epsilon used: 0.46)
# Step:103907 | Total games:1441 | Mean reward: 5.100  (epsilon used: 0.46)
# Step:104017 | Total games:1442 | Mean reward: 5.500  (epsilon used: 0.46)
# Step:104080 | Total games:1443 | Mean reward: 5.200  (epsilon used: 0.46)
# Step:104171 | Total games:1444 | Mean reward: 4.900  (epsilon used: 0.46)
# Step:104282 | Total games:1445 | Mean reward: 5.300  (epsilon used: 0.46)
# Step:104353 | Total games:1446 | Mean reward: 5.200  (epsilon used: 0.46)
# Step:104435 | Total games:1447 | Mean reward: 5.600  (epsilon used: 0.46)
# Step:104548 | Total games:1448 | Mean reward: 5.900  (epsilon used: 0.46)
# Step:104640 | Total games:1449 | Mean reward: 6.100  (epsilon used: 0.46)
# Step:104709 | Total games:1450 | Mean reward: 6.200  (epsilon used: 0.46)
# Step:104765 | Total games:1451 | Mean reward: 5.800  (epsilon used: 0.46)
# Step:104834 | Total games:1452 | Mean reward: 5.300  (epsilon used: 0.46)
# Step:104936 | Total games:1453 | Mean reward: 5.800  (epsilon used: 0.46)
# Step:105043 | Total games:1454 | Mean reward: 5.900  (epsilon used: 0.45)
# Step:105124 | Total games:1455 | Mean reward: 5.500  (epsilon used: 0.45)
# Step:105192 | Total games:1456 | Mean reward: 5.500  (epsilon used: 0.45)
# Step:105266 | Total games:1457 | Mean reward: 5.000  (epsilon used: 0.45)
# Step:105343 | Total games:1458 | Mean reward: 4.800  (epsilon used: 0.45)
# Step:105403 | Total games:1459 | Mean reward: 4.500  (epsilon used: 0.45)
# Step:105477 | Total games:1460 | Mean reward: 5.200  (epsilon used: 0.45)
# Step:105563 | Total games:1461 | Mean reward: 5.400  (epsilon used: 0.45)
# Step:105689 | Total games:1462 | Mean reward: 6.300  (epsilon used: 0.45)
# Step:105762 | Total games:1463 | Mean reward: 5.900  (epsilon used: 0.45)
# Step:105893 | Total games:1464 | Mean reward: 6.200  (epsilon used: 0.45)
# Step:105975 | Total games:1465 | Mean reward: 6.300  (epsilon used: 0.45)
# Step:106100 | Total games:1466 | Mean reward: 6.700  (epsilon used: 0.45)
# Step:106178 | Total games:1467 | Mean reward: 6.900  (epsilon used: 0.45)
# Step:106263 | Total games:1468 | Mean reward: 6.800  (epsilon used: 0.45)
# Step:106321 | Total games:1469 | Mean reward: 6.800  (epsilon used: 0.45)
# Step:106384 | Total games:1470 | Mean reward: 6.100  (epsilon used: 0.45)
# Step:106453 | Total games:1471 | Mean reward: 6.000  (epsilon used: 0.45)
# Step:106531 | Total games:1472 | Mean reward: 5.200  (epsilon used: 0.45)
# Step:106680 | Total games:1473 | Mean reward: 5.800  (epsilon used: 0.45)
# Step:106738 | Total games:1474 | Mean reward: 5.100  (epsilon used: 0.45)
# Step:106806 | Total games:1475 | Mean reward: 5.000  (epsilon used: 0.45)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 54
#      51 if len(priorized_buffer) < EXPERIENCE_REPLAY_SIZE:
#      52     continue
# ---> 54 (states_, actions_, rewards_, dones_, next_states_), importance, indices = priorized_buffer.sample(BATCH_SIZE)
#      55 importance = torch.tensor(importance, dtype=torch.float32).to(device)
#      57 states = torch.tensor(states_).to(device)
#
# Cell In[43], line 44, in PrioritizedExperienceReplayBuffer.sample(self, batch_size)
#      40 importance = self._get_importance(sample_probs[sample_indices])
#      42 states, actions, rewards, dones, next_states = zip(*experiences)
# ---> 44 return (np.array(states), np.array(actions), np.array(rewards, dtype=np.float32),
#      45         np.array(dones, dtype=np.uint8), np.array(next_states)), importance, sample_indices
#
# KeyboardInterrupt:

# %%
torch.save(net.state_dict(), "../models/Part1_DQN.dat")

# %%
print(">>> Training ends at ",datetime.datetime.now())
print("")
print("")

# %%
# Finish the wandb run, necessary in notebooks
wandb.finish()
# Out:
# VBox(children=(Label(value='0.113 MB of 0.113 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epsilon</td><td>█▇▇▇▇▆▆▆▅▅▅▅▅▅▅▄▄▄▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁</td></tr><tr><td>loss</td><td>▁▁▂▂▂▂▂▂▂▁▂▂▅▄▂▂▂▁▁▂▃▄▃▂▂▃▂▄▄▃▄▃▆▂▂▅▃▃█▅</td></tr><tr><td>loss_mean</td><td>▃▃▂▁▁▂▁▂▂▃▁▁▂▁▂▂▂▃▂▂▂▂▂▅▃▃▄▄▃▃▂▅█▃▃▄▄▄▇▄</td></tr><tr><td>reward</td><td>▂▂▂▂▂▂▂▂▅▄▁▂▂▂▂▂▂▃▄▃▂▂▂▅▁▂▃▆▃▅▃▅▆█▄▃▄▅▅▄</td></tr><tr><td>reward_mean</td><td>▂▂▂▂▂▂▁▂▁▂▂▂▂▂▁▂▂▂▁▂▂▂▃▂▃▂▃▄▅▅▆▆▆▄▆▆██▇▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epsilon</td><td>0.44886</td></tr><tr><td>loss</td><td>0.00983</td></tr><tr><td>loss_mean</td><td>0.02208</td></tr><tr><td>reward</td><td>4</td></tr><tr><td>reward_mean</td><td>5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fragrant-energy-18</strong> at: <a href='https://wandb.ai/arroch35-organitzation/Part1_DQN/runs/24cl6npg' target="_blank">https://wandb.ai/arroch35-organitzation/Part1_DQN/runs/24cl6npg</a><br/> View project at: <a href='https://wandb.ai/arroch35-organitzation/Part1_DQN' target="_blank">https://wandb.ai/arroch35-organitzation/Part1_DQN</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20241201_230835-24cl6npg\logs</code>

# %%
model=DuelingDQN(env.observation_space.shape, env.action_space.n).to(device)
model.load_state_dict(torch.load("../models/Part1_DQN_15.dat", map_location=torch.device('cpu')))
# Out:
# C:\Users\arroc\AppData\Local\Temp\ipykernel_36236\3883367449.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("../models/Part1_DQN_15.dat", map_location=torch.device('cpu')))
# <All keys matched successfully>

# %%
from PIL import Image
import time
# params
visualize = True
images = []

state, _ = env.reset()
total_reward = 0.0

while True:
    start_ts = time.time()
    if visualize:
        img = env.render()
        images.append(Image.fromarray(img))

    state_ = torch.tensor(np.array([state], copy=False))
    q_vals = model(state_).data.numpy()[0]
    action = np.argmax(q_vals)

    state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    total_reward += reward
    if done:
        break

print("Total reward: %.2f" % total_reward)
# Out:
# Total reward: 13.00

# %%
# params
gif_file = "video.gif"

# duration is the number of milliseconds between frames; this is 40 frames per second
images[0].save(gif_file, save_all=True, append_images=images[1:], duration=60, loop=0)

print("Episode export to '{}'".format(gif_file))
# Out:
# Episode export to 'video.gif'
